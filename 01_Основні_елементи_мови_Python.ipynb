# %% [markdown]
# <a href="https://colab.research.google.com/github/galushkoss/swot/blob/master/01_%D0%9E%D1%81%D0%BD%D0%BE%D0%B2%D0%BD%D1%96_%D0%B5%D0%BB%D0%B5%D0%BC%D0%B5%D0%BD%D1%82%D0%B8_%D0%BC%D0%BE%D0%B2%D0%B8_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Основні елементи мови Python
#
# Будь-яка мова програмування (як і будь-яка природна мова) складається з базових елементів. Через те що мова програмування &mdash; це штучна мова, вона має меншу кількість базових елементів.
#
# *   Алфавіт
# *   Лексема

# %% [markdown]
# ## Алфавіт мови Python
#
# Алфавіт мови програмування (як і звичайної мови) складається з тих символів, які допускається використовувати при користуванні мовою. У нашому випадку при програмуванні.
#
# Алфавіт Python складається з наступних символів:
#
# *Літери*
# : Великі та малі літери латинського алфавіту.
#
# *Цифри*
# : Цифри від 0 до 9.
#
# *Спеціальні символи*
# : Символи, які використовуються для запису команд, розділення елементів та виконання операцій. Це можуть бути:
#
# *   Знаки операцій: `+, -, *, /, %, ==, !=, <, >, <=, >=, | , &, ^, ~`
# *   Роздільники: `(, ),, {, }, ,, ., :, ;`
# *   Символ підкреслення: `_`
# *   Знак коментаря: `#`
#
# *Пробіл*
# : Символ пробілу також є частиною алфавіту
#
# На відміну від інших мов програмування символи кирилиці не є частиною алфавіту, але можуть використовуватись у коментарях, символьних рядках. Через те, що Python 3 повноцінно підтримує роботу з кодуванням Unicode кирилицею, можна писати навіть ідентифікатори. Але в практиці програмування для ідентифікаторів використовують тільки літери англійського алфавіту.

# %% [markdown]
# ### Зведена таблиця алфавіту Python
#
# | **Група символів**            | **Приклади**                                                                                 | **Примітка**                                                                              |
# |-------------------------------|----------------------------------------------------------------------------------------------|-------------------------------------------------------------------------------------------|
# | **Літери**                    | `A–Z`, `a–z`                                                                                 | Використовуються в ключових словах, ідентифікаторах. Python чутливий до регістру.         |
# | **Цифри**                     | `0–9`                                                                                        | Використовуються в числових літералах. Можуть входити до імен змінних, але не на початку. |
# | **Пробіли й керівні символи** | ` ` (space), `\t` (tab), `\n` (новий рядок)                                                  | Визначають відступи (структуру коду) та розділяють інструкції.                            |
# | **Оператори та роздільники**  | `+  -  *  /  %  **  //  =  ==  !=  <  > <= >=  ()  []  {}  ,  .  :  ;  @  \  &  \|  ^  ~  _` | Формують вирази, виклики функцій, списки, словники тощо.                                  |
# | **Рядкові лапки**             | `' " """ '''`                                                                                | Використовуються для створення рядків.                                                    |
# | **Коментарі**                 | `#`                                                                                          | Усе після `#` до кінця рядка ігнорується інтерпретатором.                                 |
# | **Символи Unicode**           | `Привіт`, `你好`, `😊`                                                                         | Дозволені в рядках і навіть у назвах змінних (але це не рекомендують).                    |

# %% [markdown]
# ## Лексема
#
# *Лексема*
# : це мінімальна одиниця мови, яка має певне самостійне значення і яку розуміє транслятор. Якщо транслятор її не розуміє, то видається повідомлення
# про помилку в програмі. За замовчуванням символи кодуються в системі UTF-8
#
# Розрізняють такі види лексем:
# * ключові (зарезервовані) слова (keywords);
# * ідентифікатори (identifiers);
# * літерали (константи);
# * операції;
# * знаки пунктуації.
#
# *Ключові слова* (keywords) в Python
# : це зарезервовані слова, які мають спеціальне значення для мови програмування.
# Вони використовуються для опису структури програми (наприклад, `if`, `for`, `while`), визначення блоків функцій і класів (`def`, `class`), логічних значень (`True`, `False`, `None`) тощо.
#
# Головне правило: ключові слова не можна використовувати як імена змінних, функцій або класів, бо інтерпретатор розпізнає їх тільки в їхньому спеціальному значенні.
#
# Ідентифікатори
# : це імена, які придумує програміст, щоб позначати свої змінні, функції, класи, модулі та інші об’єкти. Ідентифікатор може складатися з латинських літер, цифр та знака підкреслення `_`, але не може починатись із цифри.

# %% [markdown]
# # Змінні в Python
#
# *Змінна в Python*
# : це ідентифікатор, що посилається на об’єкт в оперативній пам’яті комп'ютера.
# Іншими словами, змінна не «містить» значення, а зберігає посилання на певний об’єкт (число, рядок, список тощо), який розташований десь у пам'яті ПК.
#
# Тип цього об’єкта визначається динамічно під час виконання програми.
#
# Якщо простішими словами, то *Змінна в Python*
# : це іменована «коробочка» в пам’яті комп’ютера, у якій зберігається певне значення. Ім’я змінної придумує програміст (це ідентифікатор), а значення можна змінювати під час виконання програми.

# %% [markdown]
# ## Типи змінних
#
# | **Тип даних**                | **Приклад**                          | **Опис**                                                     |
# |------------------------------|--------------------------------------|--------------------------------------------------------------|
# | `int` (ціле число)           | `x = 42`                             | Цілі числа (додатні, від’ємні, нуль).                        |
# | `float` (дійсне число)       | `pi = 3.14`                          | Числа з дробовою частиною (плаваюча кома).                   |
# | `complex` (комплексне число) | `z = 2 + 3j`                         | Комплексні числа, мають дійсну й уявну частину.              |
# | `str` (рядок)                | `name = "Python"`                    | Текстові дані в одинарних, подвійних або потрійних лапках.   |
# | `bool` (логічний тип)        | `flag = True`                        | Логічні значення `True` або `False`.                         |
# | `list` (список)              | `numbers = [1, 2, 3]`                | Упорядкована змінювана послідовність елементів.              |
# | `tuple` (кортеж)             | `point = (10, 20)`                   | Упорядкована **незмінювана** послідовність елементів.        |
# | `set` (множина)              | `colors = {"red", "green"}`          | Невпорядкована колекція унікальних елементів.                |
# | `dict` (словник)             | `user = {"name": "Ivan", "age": 15}` | Набір пар «ключ–значення».                                   |
# | `NoneType`                   | `x = None`                           | Спеціальний тип, що означає «порожнє значення» або «нічого». |
#
# У наступному блоці приклади змінних відповідних типів:

# %%
# int – цілі числа
x = 42
print(x, type(x))  # 42 <class 'int'>

# float – числа з дробовою частиною
pi = 3.14
print(pi, type(pi))  # 3.14 <class 'float'>

# complex – комплексні числа
z = 2 + 3j
print(z, type(z))  # (2+3j) <class 'complex'>

# str – рядки (текст)
name = "Python"
print(name, type(name))  # Python <class 'str'>

# bool – логічні значення
flag = True
print(flag, type(flag))  # True <class 'bool'>

# list – упорядкована змінювана колекція
numbers = [1, 2, 3]
print(numbers, type(numbers))  # [1, 2, 3] <class 'list'>

# tuple – упорядкована незмінювана колекція
point = (10, 20)
print(point, type(point))  # (10, 20) <class 'tuple'>

# set – невпорядкована колекція унікальних елементів
colors = {"red", "green"}
print(colors, type(colors))  # {'red', 'green'} <class 'set'>

# dict – словник, набір пар "ключ–значення"
user = {"name": "Ivan", "age": 15}
print(user, type(user))  # {'name': 'Ivan', 'age': 15} <class 'dict'>

# NoneType – спеціальний тип "нічого"
x = None
print(x, type(x))  # None <class 'NoneType'>
# Out:
# 42 <class 'int'>
# 3.14 <class 'float'>
# (2+3j) <class 'complex'>
# Python <class 'str'>
# True <class 'bool'>
# [1, 2, 3] <class 'list'>
# (10, 20) <class 'tuple'>
# {'green', 'red'} <class 'set'>
# {'name': 'Ivan', 'age': 15} <class 'dict'>
# None <class 'NoneType'>

# %% [markdown]
# Тип змінної може не тільки динамічно визначатися, але й динамічно змінюватися. Наприклад:

# %%
x = 42
print(x, type(x))
x = "Hello Python"
print(x, type(x))
# Out:
# 42 <class 'int'>
# Hello Python <class 'str'>

# %% [markdown]
# ## Присвоєння значень змінним
#
# Для присвоєння значення змінній (простіше: для того, щоб записати значення у змінну) у Python використовується оператор `=`:

# %%
some_var = 56 # У змінну some_var записали значення 56

# %% [markdown]
# Крім того, Python дозволяє в одному рядку присвоювати значення одразу кільком змінним:

# %%
var_1 = var_2 = var_3 = 456
print(f"{var_1}, {var_2}, {var_3}")
# Out:
# 456, 456, 456

# %% [markdown]
# Також можна в одному рядочку просвоювати різні значення різним змінним:

# %%
v1, v2, v3 = 23, 34, 56
print(f"{v1}, {v2}, {v3}")
# Out:
# 23, 34, 56

# %% [markdown]
# Кількість елементів ліворуч і праворуч від оператора присвоювання має бути однакова, інакше буде видано повідомлення про синтаксичну помилку

# %%
v1, v2, v3 = 23, 34, 56, 37
print(f"{v1}, {v2}, {v3}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-1150389041.py in <cell line: 0>()
# ----> 1 v1, v2, v3 = 23, 34, 56, 37
#       2 print(f"{v1}, {v2}, {v3}")
#
# ValueError: too many values to unpack (expected 3)

# %% [markdown]
# Для того, щоб уникнути цієї помилки можна використовувати оператор `*`. Його треба поставити перед ідентифікатором однієї зі змінних, тоді в цю змінну запишеться список значень, які не влізають в інші змінні:

# %%
v1, *v2, v3 = 23, 34, 56, 37
print(f"{v1}, {v2}, {v3}")
# Out:
# 23, [34, 56], 37

# %%
v1, v2, *v3 = 23, 34, 56, 37
print(f"{v1}, {v2}, {v3}")
# Out:
# 23, 34, [56, 37]
